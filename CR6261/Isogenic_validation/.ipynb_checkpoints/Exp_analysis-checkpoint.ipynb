# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style('white')

import os
import collections
import glob
from scipy.stats import pearsonr
import scipy.optimize
import scipy.stats

# %%
mut_list = pd.read_csv('mut-list-exp.csv',  sep=',', dtype={'geno' : str}, index_col=[0])
mut_list
# Out:
#   shortname           geno  exp_mean   exp_sem
# a         1  "10000000000"  3.275724  0.066922
# b         2  "01000000000"  3.233095  0.027723
# c        12  "11000000000"  3.256464  0.044148
# d         6  "00000100000"  3.145927  0.046470
# e        67  "00000110000"  3.259850  0.051516
# g      1267  "11000110000"  3.166982  0.027866
# h     12678  "11000111000"  3.263860  0.027448
# m      germ  "00000000000"  3.141164  0.048265
# n       som  "11111111111"  3.267142  0.052119

# %%
import csv
old_rep2=['20210327_isogenic_FITC/csv/export_Specimen_114_A1_A01_001_germ_1.csv','20210327_isogenic_FITC/csv/export_Specimen_150_D1_D01_023_som_1.csv']
old_rep1=['20210327_isogenic_FITC/csv/export_Specimen_114_A1_A01_001_germ_2.csv','20210327_isogenic_FITC/csv/export_Specimen_150_D1_D01_023_som_2.csv']
rep1 =['20210327_isogenic_FITC/csv/export_Specimen_001_A1_A01_001_1_rep1.csv','20210327_isogenic_FITC/csv/export_Specimen_013_B1_B01_013_1267_1.csv','20210327_isogenic_FITC/csv/export_Specimen_025_C1_C01_025_12_1.csv','20210327_isogenic_FITC/csv/export_Specimen_038_D1_D01_038_12678_1.csv','20210327_isogenic_FITC/csv/export_Specimen_052_E4_E04_052_67_1.csv']
rep2 =['20210327_isogenic_FITC/csv/export_Specimen_114_A1_A01_001_1_rep2.csv','20210327_isogenic_FITC/csv/export_Specimen_209_B1_B01_041_1267_rep2.csv','20210327_isogenic_FITC/csv/export_Specimen_221_D1_D01_053_12678_rep2.csv','20210327_isogenic_FITC/csv/export_Specimen_197_C1_C01_029_12_rep2.csv','20210327_isogenic_FITC/csv/export_Specimen_151_E1_E01_012_67_rep2.csv']
rep3 =['20210327_isogenic_FITC/csv/export_Specimen_114_A1_A01_001_2_rep1.csv','20210327_isogenic_FITC/csv/export_Specimen_151_E1_E01_012_6_rep1.csv']
rep4 =['20210327_isogenic_FITC/csv/export_Specimen_114_A1_A01_001_2_rep2.csv','20210327_isogenic_FITC/csv/export_Specimen_151_E1_E01_012_6_rep2.csv']
fitc_old_rep1 = []
for file in old_rep1:
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            fitc_old_rep1.append(float(row[6]))
old_rep1_min = min(fitc_old_rep1)
fitc_old_rep2 = []
for file in old_rep2:
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            fitc_old_rep2.append(float(row[6]))
old_rep2_min = min(fitc_old_rep2)
fitc_rep1 = []
for file in rep1:
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            fitc_rep1.append(float(row[6]))
rep1_min = min(fitc_rep1)
fitc_rep2 = []
for file in rep2:
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            fitc_rep2.append(float(row[6]))
rep2_min = min(fitc_rep2)
fitc_rep3 = []
for file in rep3:
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            fitc_rep3.append(float(row[6]))
rep3_min = min(fitc_rep3)
fitc_rep4 = []
for file in rep4:
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            fitc_rep4.append(float(row[6]))
rep4_min = min(fitc_rep4)
print(old_rep1_min,old_rep2_min,rep1_min,rep2_min,rep3_min,rep4_min)
# Out:
# -67.68 -50.4 -193.8 -133.76 -6206.92 -122.36

# %%
FITC_means=[]
FITC_stdev=[]
names=[]
for file in old_rep1:
    names.append(file)
    FITC_input=[]
    FITC_adj=[]
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            FITC_input.append(float(row[6]))
        for item in FITC_input:
            FITC_a = item - old_rep1_min + 1
            FITC_adj.append(float(FITC_a))
        FITC_fluor = np.asarray(FITC_adj)
        FITC_log_fluor = np.log10(FITC_fluor)
        FITC_avg = np.average(FITC_log_fluor)
        FITC_std = np.std(FITC_log_fluor)
        FITC_means.append(FITC_avg)
        FITC_stdev.append(FITC_std)
for file in old_rep2:
    names.append(file)
    FITC_input=[]
    FITC_adj=[]
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            FITC_input.append(float(row[6]))
        for item in FITC_input:
            FITC_a = item - old_rep2_min + 1
            FITC_adj.append(float(FITC_a))
        FITC_fluor = np.asarray(FITC_adj)
        FITC_log_fluor = np.log10(FITC_fluor)
        FITC_avg = np.average(FITC_log_fluor)
        FITC_std = np.std(FITC_log_fluor)
        FITC_means.append(FITC_avg)
        FITC_stdev.append(FITC_std)
for file in rep1:
    names.append(file)
    FITC_input=[]
    FITC_adj=[]
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            FITC_input.append(float(row[6]))
        for item in FITC_input:
            FITC_a = item - rep1_min + 1
            FITC_adj.append(float(FITC_a))
        FITC_fluor = np.asarray(FITC_adj)
        FITC_log_fluor = np.log10(FITC_fluor)
        FITC_avg = np.average(FITC_log_fluor)
        FITC_std = np.std(FITC_log_fluor)
        FITC_means.append(FITC_avg)
        FITC_stdev.append(FITC_std)
for file in rep2:
    names.append(file)
    FITC_input=[]
    FITC_adj=[]
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            FITC_input.append(float(row[6]))
        for item in FITC_input:
            FITC_a = item - rep2_min + 1
            FITC_adj.append(float(FITC_a))
        FITC_fluor = np.asarray(FITC_adj)
        FITC_log_fluor = np.log10(FITC_fluor)
        FITC_avg = np.average(FITC_log_fluor)
        FITC_std = np.std(FITC_log_fluor)
        FITC_means.append(FITC_avg)
        FITC_stdev.append(FITC_std)
for file in rep3:
    names.append(file)
    FITC_input=[]
    FITC_adj=[]
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            FITC_input.append(float(row[6]))
        for item in FITC_input:
            FITC_a = item - rep3_min + 1
            FITC_adj.append(float(FITC_a))
        FITC_fluor = np.asarray(FITC_adj)
        FITC_log_fluor = np.log10(FITC_fluor)
        FITC_avg = np.average(FITC_log_fluor)
        FITC_std = np.std(FITC_log_fluor)
        FITC_means.append(FITC_avg)
        FITC_stdev.append(FITC_std)
for file in rep4:
    names.append(file)
    FITC_input=[]
    FITC_adj=[]
    with open(file, "r") as csvfile:
        csvreader = csv.reader(csvfile)
        next(csvreader,None)
        for row in csvreader:
            FITC_input.append(float(row[6]))
        for item in FITC_input:
            FITC_a = item - rep4_min + 1
            FITC_adj.append(float(FITC_a))
        FITC_fluor = np.asarray(FITC_adj)
        FITC_log_fluor = np.log10(FITC_fluor)
        FITC_avg = np.average(FITC_log_fluor)
        FITC_std = np.std(FITC_log_fluor)
        FITC_means.append(FITC_avg)
        FITC_stdev.append(FITC_std)
lists = zip(names,FITC_means,FITC_stdev)
summary = pd.DataFrame(lists, columns=['file','mean','stdev'])
summary
# Out:
#                                                  file      mean     stdev
# 0   20210327_isogenic_FITC/csv/export_Specimen_114...  3.882291  0.586215
# 1   20210327_isogenic_FITC/csv/export_Specimen_150...  3.923869  0.598812
# 2   20210327_isogenic_FITC/csv/export_Specimen_114...  3.799542  0.631184
# 3   20210327_isogenic_FITC/csv/export_Specimen_150...  3.866142  0.639117
# 4   20210327_isogenic_FITC/csv/export_Specimen_001...  3.966724  0.616863
# 5   20210327_isogenic_FITC/csv/export_Specimen_013...  3.935438  0.563318
# 6   20210327_isogenic_FITC/csv/export_Specimen_025...  3.811967  0.637274
# 7   20210327_isogenic_FITC/csv/export_Specimen_038...  3.617845  0.504964
# 8   20210327_isogenic_FITC/csv/export_Specimen_052...  3.718490  0.546137
# 9   20210327_isogenic_FITC/csv/export_Specimen_114...  3.800137  0.628023
# 10  20210327_isogenic_FITC/csv/export_Specimen_209...  3.576888  0.603981
# 11  20210327_isogenic_FITC/csv/export_Specimen_221...  3.471882  0.529003
# 12  20210327_isogenic_FITC/csv/export_Specimen_197...  3.698666  0.651268
# 13  20210327_isogenic_FITC/csv/export_Specimen_151...  3.628387  0.566033
# 14  20210327_isogenic_FITC/csv/export_Specimen_114...  4.341220  0.301138
# 15  20210327_isogenic_FITC/csv/export_Specimen_151...  4.193038  0.272228
# 16  20210327_isogenic_FITC/csv/export_Specimen_114...  3.801204  0.614980
# 17  20210327_isogenic_FITC/csv/export_Specimen_151...  3.687081  0.580817

# %%
mutants = ['1','2','6','12','67','1267','12678','som','germ']
means=[]
sems=[]
for mutant in mutants:
    mean = summary[summary['file'].str.contains("_%s_"%mutant)]['mean'].mean(axis=0)
    sem = summary[summary['file'].str.contains("_%s_"%mutant)]['mean'].sem(axis=0)
    means.append(mean)
    sems.append(sem)
lists2=zip(mutants,means,sems)
summary2 = pd.DataFrame(lists2, columns=['shortname','iso_mean','iso_sem'])
summary2
# Out:
#   shortname  iso_mean   iso_sem
# 0         1  3.883430  0.083293
# 1         2  4.071212  0.270008
# 2         6  3.940060  0.252979
# 3        12  3.755316  0.056651
# 4        67  3.673438  0.045051
# 5      1267  3.756163  0.179275
# 6     12678  3.544863  0.072982
# 7       som  3.895005  0.028863
# 8      germ  3.840917  0.041375

# %%
toplot=pd.merge(summary2,mut_list,on='shortname')
toplot
# Out:
#   shortname  iso_mean   iso_sem           geno  exp_mean   exp_sem
# 0         1  3.883430  0.083293  "10000000000"  3.275724  0.066922
# 1         2  4.071212  0.270008  "01000000000"  3.233095  0.027723
# 2         6  3.940060  0.252979  "00000100000"  3.145927  0.046470
# 3        12  3.755316  0.056651  "11000000000"  3.256464  0.044148
# 4        67  3.673438  0.045051  "00000110000"  3.259850  0.051516
# 5      1267  3.756163  0.179275  "11000110000"  3.166982  0.027866
# 6     12678  3.544863  0.072982  "11000111000"  3.263860  0.027448
# 7       som  3.895005  0.028863  "11111111111"  3.267142  0.052119
# 8      germ  3.840917  0.041375  "00000000000"  3.141164  0.048265

# %%
sns.set_style('ticks')
from matplotlib.ticker import FixedLocator, FixedFormatter
plt.rcParams['font.sans-serif'] = "Arial"
# Then, "ALWAYS use sans-serif fonts"
plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['axes.linewidth'] = 0.5
flierprops = dict(marker='o', markersize=2)
plt.figure(figsize=(1,1))
#x_locator = FixedLocator([6,7,8,9,10])
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(toplot['iso_mean'], toplot['exp_mean'])
xs = np.array([3,4.5])
plt.plot(xs, xs, 'k-')
plt.plot(xs, slope*xs + intercept, 'k:')
corr, _ = pearsonr(toplot['iso_mean'], toplot['exp_mean'])

plt.errorbar(x=toplot['iso_mean'],
                 y=toplot['exp_mean'],
                 xerr=toplot['iso_sem'],
                 yerr=toplot['exp_sem'],
                 linestyle='None',
                 linewidth=1,
                 marker='o',
                 markersize=4,
                 markeredgecolor='k',
                 markeredgewidth=0.5,
                 ecolor='k')
import scipy.stats
plt.xticks(ticks=[3,3.5,4,4.5],labels=['3','3.5','4','4.5'],fontsize=7)
plt.yticks(ticks=[3,3.5,4,4.5],labels=['3','3.5','4','4.5'],fontsize=7)
#plt.legend(fontsize=7,bbox_to_anchor=(0.5, 1.1), loc='right')
plt.tick_params(length=2.5,width=0.5)
#plt.legend(loc='best',fontsize=7)
plt.xlabel('Exp mean fluor:\nisogenic FACS',fontsize=7,labelpad=0.5)
plt.ylabel('Exp mean bin:\nTiteseq',fontsize=7,labelpad=1)
#plt.title('r =  %.2f' % corr,fontsize=8,y=1)
#plt.title('CR9114, Comparison of Titeseq to isogenic measurement\n$R^2=%0.3f$' % r_value**2)
plt.axis('square')
plt.savefig('6261expvalidation.png',transparent=True, dpi=600,bbox_inches='tight')
print(corr)
# Out:
# -0.24593443295892187
