# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style('white')

import os
import collections
import glob
from scipy.stats import pearsonr
import scipy.optimize
import scipy.stats

# %%
results = pd.DataFrame(pd.read_csv('../../../../CR6261/Isogenic_validation/Isogenic_Kd/Mutants/fitted_Kds.csv'))
results
# Out:
#    antigen  shortname replicate  run_id         KD    KD_err  KD_titeseq  \
# 0       H1        1,2         1       1  -9.152523  0.321791    9.278592
# 1       H1        1,2         2      19  -9.277189  0.384465    9.278592
# 2       H1    1,2,6,7         1       4  -9.092682  0.285362    9.343454
# 3       H1    1,2,6,7         2      22  -9.229987  0.230932    9.343454
# 4       H1        som     1_old      12  -9.504139  0.233841    9.506654
# 5       H1        som     2_old      16  -9.503407  0.225267    9.506654
# 6       H9        1,2         1       6  -9.176412  0.683471    9.067835
# 7       H9        1,2         2      24  -9.054685  0.680104    9.067835
# 8       H9    1,2,6,7         1       8  -9.767006  0.289334    9.807098
# 9       H9    1,2,6,7         2      26  -9.866163  0.312003    9.807098
# 10      H9  1,2,6,7,8         1       9  -9.885418  0.290101   10.001743
# 11      H9  1,2,6,7,8         2      27  -9.958268  0.289318   10.001743
# 12      H9        6,7         1       7  -8.944757  0.982511    8.869847
# 13      H9        6,7         2      25  -8.970928  0.901182    8.869847
# 14      H9        som     1_old      13 -10.190717  0.254492   10.094744
# 15      H9        som     2_old      17 -10.160267  0.202185   10.094744
#
#     KD_titeseq_err
# 0         0.043819
# 1         0.043819
# 2         0.015493
# 3         0.015493
# 4         0.016688
# 5         0.016688
# 6         0.144001
# 7         0.144001
# 8         0.008562
# 9         0.008562
# 10        0.024947
# 11        0.024947
# 12        0.099096
# 13        0.099096
# 14        0.014203
# 15        0.014203

# %%
g = results.groupby(['antigen', 'shortname'])
results_merge = pd.DataFrame({
    'KD' : g.mean()['KD'],
    'KD_std' : g.std()['KD'],
    'KD_titeseq' : g['KD_titeseq'].mean(),
    'KD_titeseq_err' : g['KD_titeseq_err'].mean()
})

results_merge = results_merge.append(pd.DataFrame([[-7,np.nan,7,np.nan]], index=[('H1', 'ger')], columns=results_merge.columns))
results_merge = results_merge.append(pd.DataFrame([[-7,np.nan,7,np.nan]], index=[('H9', 'ger')], columns=results_merge.columns))
results_merge
# Out:
#                           KD    KD_std  KD_titeseq  KD_titeseq_err
# antigen shortname
# H1      1,2        -9.214856  0.088152    9.278592        0.043819
#         1,2,6,7    -9.161335  0.097090    9.343454        0.015493
#         som        -9.503773  0.000517    9.506654        0.016688
# H9      1,2        -9.115549  0.086074    9.067835        0.144001
#         1,2,6,7    -9.816585  0.070114    9.807098        0.008562
#         1,2,6,7,8  -9.921843  0.051513   10.001743        0.024947
#         6,7        -8.957842  0.018506    8.869847        0.099096
#         som       -10.175492  0.021531   10.094744        0.014203
# H1      ger        -7.000000       NaN    7.000000             NaN
# H9      ger        -7.000000       NaN    7.000000             NaN

# %%
sns.set_style('ticks')
from matplotlib.ticker import FixedLocator, FixedFormatter
#sns.set_context('notebook')
plot_list = results_merge[~results_merge['KD_titeseq'].isna()]
plt.rcParams['font.sans-serif'] = "Arial"
# Then, "ALWAYS use sans-serif fonts"
plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['axes.linewidth'] = 0.5
flierprops = dict(marker='o', markersize=2)
plt.figure(figsize=(1.5,1.5))
x_locator = FixedLocator([7,8,9,10,11])
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(-plot_list['KD'], plot_list['KD_titeseq'])
xs = np.array([7,10])
plt.plot(xs, xs, 'k-')
plt.plot(xs, slope*xs + intercept, 'k:')
corr, _ = pearsonr(-plot_list['KD'], plot_list['KD_titeseq'])

colordict = {'H1':'tomato', 'H9':'rebeccapurple'}
for ag,color in colordict.items():
    to_plot = plot_list.loc[ag,:]
    plt.errorbar(x=-to_plot['KD'],
                 y=to_plot['KD_titeseq'],
                 xerr=to_plot['KD_std'],
                 yerr=to_plot['KD_titeseq_err'],
                 linestyle='None',
                 linewidth=1,
                 marker='o',
                 markersize=4,
                 markeredgecolor='k',
                 markeredgewidth=0.5,
                 label=ag,
                 ecolor='k',
                color=color)
import scipy.stats
plt.xticks(ticks=[7,8,9,10,11],labels=['7','8','9','10','11'],fontsize=7)
plt.yticks(ticks=[7,8,9,10,11],labels=['7','8','9','10','11'],fontsize=7)
#plt.legend(fontsize=7,bbox_to_anchor=(0.5, 1.1), loc='right')
plt.tick_params(length=2.5,width=0.5)
#plt.legend(loc='best',fontsize=7)
plt.xlabel(r'$-\log K_d$ isogenic FACS',fontsize=7,labelpad=0)
plt.ylabel(r'$-\log K_d$ Titeseq',fontsize=7,labelpad=0)
#plt.title('r =  %.2f' % corr,fontsize=8,y=1)
#plt.title('CR9114, Comparison of Titeseq to isogenic measurement\n$R^2=%0.3f$' % r_value**2)
plt.axis('square')
plt.savefig('6261validation.png',transparent=True, dpi=600,bbox_inches='tight')
print(corr)
# Out:
# 0.9973843703526353
